# %% [markdown]
# ## Problem
# > In this assignment you will apply the concepts learn so far regarding python, numpy, matplotlib and pandas. In one of the class exercise we studied how to draw candlestick chart for three candle data. Candlestick charting is commonly used to understand stock market time series data and patterns within that data. In this assignment, you will download [SPY.CSV](./SPY.csv) file from Moodle and try to find following 3 candle patterns shown in diagrams within that data.

# %% [markdown]
# > ![image.png](attachment:image.png)

# %% [markdown]
# > Once these pattern is identified for for various date, save these three candles for drawing and verification. You should draw grid of three candle patterns as shown below as illustration. The example below shows organization of visualization by copying same pattern / date multiple time. In your case, you will have several different date patterns that looks like patterns shown above. You must also submit your approach for finding these patterns (data transformation, matching etc.).
# > ![image.png](attachment:image.png)

# %% [markdown]
# ## My Answer

# %%
import os
import pandas as pd
import matplotlib as mp
import mplfinance as mpf

# %%
filename = "SPY.csv"
data = pd.read_csv(filename, index_col=0, parse_dates=True)

## show first 5 sample
data.head(5)
# Out:
#               Open    High     Low   Close      Volume  Dividend  Split  \
# Date
# 2017-07-26  247.75  247.79  247.13  247.43  44669097.0       0.0    1.0
# 2017-07-25  247.68  247.80  247.16  247.42  52685280.0       0.0    1.0
# 2017-07-24  246.79  246.98  246.28  246.82  44565029.0       0.0    1.0
# 2017-07-21  246.44  246.91  246.18  246.88  82340759.0       0.0    1.0
# 2017-07-20  247.28  247.42  246.47  247.10  43011325.0       0.0    1.0
#
#             Adj_Open  Adj_High  Adj_Low  Adj_Close  Adj_Volume
# Date
# 2017-07-26    247.75    247.79   247.13     247.43  44669097.0
# 2017-07-25    247.68    247.80   247.16     247.42  52685280.0
# 2017-07-24    246.79    246.98   246.28     246.82  44565029.0
# 2017-07-21    246.44    246.91   246.18     246.88  82340759.0
# 2017-07-20    247.28    247.42   246.47     247.10  43011325.0

# %%
mpf.plot(data)

# %%
## use adjusted value only
d = data.loc[:, ['Adj_Open', 'Adj_High', 'Adj_Low', 'Adj_Close']]
d.head(3)
# Out:
#             Adj_Open  Adj_High  Adj_Low  Adj_Close
# Date
# 2017-07-26    247.75    247.79   247.13     247.43
# 2017-07-25    247.68    247.80   247.16     247.42
# 2017-07-24    246.79    246.98   246.28     246.82

# %%
data = d.rename(columns={'Adj_Open':'Open', 'Adj_High':'High', 'Adj_Low':'Low', 'Adj_Close':'Close'})
data.head(3)
# Out:
#               Open    High     Low   Close
# Date
# 2017-07-26  247.75  247.79  247.13  247.43
# 2017-07-25  247.68  247.80  247.16  247.42
# 2017-07-24  246.79  246.98  246.28  246.82

# %%
mpf.plot(data[0:10])

# %%
mpf.plot(data[10:0:-1], type='candle')

# %%
data=data[::-1].copy()
data.head(5)
# Out:
#                  Open       High        Low      Close
# Date
# 1993-01-29  27.465904  27.465904  27.328481  27.447165
# 1993-02-01  27.468630  27.643550  27.468630  27.643550
# 1993-02-02  27.624695  27.724648  27.568471  27.699660
# 1993-02-03  27.748979  28.017659  27.730234  27.998914
# 1993-02-04  28.092393  28.167356  28.036171  28.111134

# %%
mpf.plot(data[0:10], type='candle')

# %%
def get_cell_from_DF(df, row_index, column_index):
    return df.iloc[row_index, column_index]

# test function
get_cell_from_DF(data, 0, 0)
# Out:
# 27.46590429

# %% [markdown]
# ### Analysis of the patterns
# The search/match result is really dependent on how you interpret the pattern.
# * Is it a quantitative or qualitative pattern?
# * Simple quantitative or complex quantitative?
# * correlation?
#
# Base on questions above, I divide it into serveral levels:
# 1. Only consider qualitative portraits for each candle
#   * close>open?
#
# 2. Consider simple quantitative portraits for each candle with high/low
#   * close>open?
#   * high/low>open/close?
#
# 3. Consider simple qualitative portraits for each candle and their simple quantitative relationships (only adjacent open/close
#   * close>open?
#   * high/low>open/close?
#   * first.open/close ? second.open/close, second.open/close ? third.open/close
#
# 4. Consider simple quantitative portraits for each candle and their simple quantitative relationships (only adjacent open/close/high/low)
#   * close>open?
#   * high/low>open/close?
#   * first.open/close ? second.open/close, second.open/close ? third.open/close
#   * first.high/low ? second.high/low, second.high/low ? third.high/low
#
# 5. Consider simple quantitative portraits for each candle and their simple quantitative relationships (interrelation open/close/high/low)
#   * close>open?
#   * high/low>open/close?
#   * first.open/close ? second.open/close, second.open/close ? third.open/close
#   * first.high/low ? second.high/low, second.high/low ? third.high/low
#   * ...

# %%
def pattern1(df, i1, i2, i3, level=1):
    # returned value
    is_matched = False
    
    # level=1
    
    ## first candle
    ### close <= open
    is_matched = True if get_cell_from_DF(df, i1, 3) <= get_cell_from_DF(df, i1, 0) else False
   
    ## second candle
    ### close >= open
    is_matched = True if get_cell_from_DF(df, i2, 3) >= get_cell_from_DF(df, i2, 0) else False
    
    ## third candle
    ### close >= open
    is_matched = is_matched if get_cell_from_DF(df, i3, 3) >= get_cell_from_DF(df, i3, 0) else False
    
    # level=2
    if level>=2:
        
        ## first candle
        ### close = low
        is_matched = is_matched if get_cell_from_DF(df, i1, 3) == get_cell_from_DF(df, i1, 2) else False
        ### open  <= high
        is_matched = is_matched if get_cell_from_DF(df, i1, 0) <= get_cell_from_DF(df, i1, 1) else False

        ## second candle
        ### open >= low
        is_matched = is_matched if get_cell_from_DF(df, i2, 0) >= get_cell_from_DF(df, i2, 2) else False
        ### close < high
        is_matched = is_matched if get_cell_from_DF(df, i2, 3) <= get_cell_from_DF(df, i2, 1) else False

        ## third candle
        ### open >= low
        is_matched = is_matched if get_cell_from_DF(df, i3, 0) >= get_cell_from_DF(df, i3, 2) else False
        #3# close = high 
        is_matched = is_matched if get_cell_from_DF(df, i3, 3) == get_cell_from_DF(df, i3, 1) else False
    
    # level=3
    if level>=3:
        ## second.close <= first.close
        is_matched = is_matched if get_cell_from_DF(df, i2, 3) <= get_cell_from_DF(df, i1, 3) else False
        ## second.close <= third.open
        is_matched = is_matched if get_cell_from_DF(df, i2, 3) <= get_cell_from_DF(df, i3, 0) else False
        
    # level>=4
    if level>=4:
        pass
    
    return is_matched

# %%
pattern1(data, 0,1,2, level=2)
# Out:
# False

# %%
# find the first pattern
data.shape
# Out:
# (6169, 4)

# %%
def find_pattern(dataset, pattern, level=2):
    window_size = 3
    stride = 1
    offset = window_size // 2
    
    # index list stores indice of the middle of candles groups matching the pattern
    index_list = list()
    for i in range(offset, len(data)-offset, stride):
        if pattern(data, i-1, i, i+1, level=level):
            index_list.append(i)
    return index_list

# %%
# number of groups matching the pattern 1
index_list1 = find_pattern(data, pattern1, 3)
print(f"numbers of matched groups: {len(index_list1)}")
# Out:
# numbers of matched groups: 2

# %%
# visuualize those matched groups
for e in index_list1:
    mpf.plot(data[e-1:e+2], type="candle")

# %%
def pattern2(df, i1, i2, i3, level=2):
    # returned value
    is_matched = False
    
    # level=1
    
    ## first candle
    ### close >= open
    is_matched = True if get_cell_from_DF(df, i1, 3) >= get_cell_from_DF(df, i1, 0) else False
   
    ## second candle
    ### close <= open
    is_matched = is_matched if get_cell_from_DF(df, i2, 3) <= get_cell_from_DF(df, i2, 0) else False
    
    ## third candle
    ### close >= open
    is_matched = is_matched if get_cell_from_DF(df, i3, 3) >= get_cell_from_DF(df, i3, 0) else False
    
    # level=2
    if level>=2:
        
        ## first candle
        ### close <= high
        is_matched = is_matched if get_cell_from_DF(df, i1, 3) <= get_cell_from_DF(df, i1, 1) else False
        ### open  >= low
        is_matched = is_matched if get_cell_from_DF(df, i1, 0) >= get_cell_from_DF(df, i1, 2) else False

        ## second candle
        ### open <= high
        is_matched = is_matched if get_cell_from_DF(df, i2, 0) <= get_cell_from_DF(df, i2, 1) else False
        ### close >= low
        is_matched = is_matched if get_cell_from_DF(df, i2, 3) >= get_cell_from_DF(df, i2, 2) else False

        ## third candle
        ### open >= low
        is_matched = is_matched if get_cell_from_DF(df, i3, 0) >= get_cell_from_DF(df, i3, 2) else False
        #3# close <= high 
        is_matched = is_matched if get_cell_from_DF(df, i3, 3) == get_cell_from_DF(df, i3, 1) else False
    
    # level>=3
    if level>=3:
        pass
    
    return is_matched

# %%
# test pattern 2
pattern2(data, 0,1,2)
# Out:
# False

# %%
index_list2 = find_pattern(data, pattern2, level=2)
print(f"numbers of matched groups: {len(index_list2)}")
# Out:
# numbers of matched groups: 75

# %%
# visuualize the first matched group
position = index_list2[0]
mpf.plot(data.iloc[[position-1, position, position+1], :], type="candle")

# %%
def pattern3(df, i1, i2, i3, i4, level=1):
    # returned value
    is_matched = False
    
    # level=1
    
    ## candle 1
    ### close <= open
    is_matched = True if get_cell_from_DF(df, i1, 3) <= get_cell_from_DF(df, i1, 0) else False
   
    ## candle 2
    ### close <= open
    is_matched = is_matched if get_cell_from_DF(df, i2, 3) <= get_cell_from_DF(df, i2, 0) else False
    
    ## candle 3
    ### close <= open
    is_matched = is_matched if get_cell_from_DF(df, i3, 3) <= get_cell_from_DF(df, i3, 0) else False
    
    ## candle 4
    ### close >= open
    is_matched = is_matched if get_cell_from_DF(df, i3, 3) >= get_cell_from_DF(df, i3, 0) else False
    
    # level=2
    if level>=2:
        
        ## candle 1
        ### close >= low
        is_matched = is_matched if get_cell_from_DF(df, i1, 3) >= get_cell_from_DF(df, i1, 2) else False
        ### open  <= high
        is_matched = is_matched if get_cell_from_DF(df, i1, 0) <= get_cell_from_DF(df, i1, 1) else False

        ## candle 2
        ### close >= low
        is_matched = is_matched if get_cell_from_DF(df, i2, 3) >= get_cell_from_DF(df, i2, 2) else False
        ### open  <= high
        is_matched = is_matched if get_cell_from_DF(df, i2, 0) <= get_cell_from_DF(df, i2, 1) else False

        ## candle 3
        ### close >= low
        is_matched = is_matched if get_cell_from_DF(df, i3, 3) >= get_cell_from_DF(df, i3, 2) else False
        ### open  <= high
        is_matched = is_matched if get_cell_from_DF(df, i3, 0) <= get_cell_from_DF(df, i3, 1) else False
        
        ### close <= high
        is_matched = is_matched if get_cell_from_DF(df, i1, 3) <= get_cell_from_DF(df, i1, 1) else False
        ### open  >= low
        is_matched = is_matched if get_cell_from_DF(df, i1, 0) >= get_cell_from_DF(df, i1, 2) else False
    
    # level>=3
    if level>=3:
        ## i2.open <= i1.open
        is_matched = is_matched if get_cell_from_DF(df, i2, 0) <= get_cell_from_DF(df, i1, 0) else False
        ## i3.open <= i2.open 
        is_matched = is_matched if get_cell_from_DF(df, i3, 0) <= get_cell_from_DF(df, i2, 0) else False
        ## i4.open <= i3.open 
        is_matched = is_matched if get_cell_from_DF(df, i4, 0) <= get_cell_from_DF(df, i3, 0) else False
    
    return is_matched

# %%
# test pattern3
pattern3(data, 0,1,2,3, level=1)
# Out:
# False

# %%
def find_pattern3(dataset, pattern, level=2):
    window_size = 4
    stride = 1
    offset = window_size // 2
    
    # index list stores indice of the middle of candles groups matching the pattern
    index_list = list()
    for i in range(offset, len(data)-offset, stride):
        if pattern(data, i-2, i-1, i, i+1, level=level):
            index_list.append(i)
    return index_list

# %%
index_list3 = find_pattern3(data, pattern3, level=3)

# %%
len(index_list3)
# Out:
# 4

# %%
for e in index_list3:
    mpf.plot(data[e-2:e+2], type='candle')
